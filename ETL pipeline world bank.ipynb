# %%
import pandas as pd

# %% [markdown]
# ### Part 1: Load dataset

# %%
df_projects = pd.read_csv('projects_data.csv', low_memory=False)

# %%
print(df_projects.shape)
df_projects.head()
# Out:
# (18248, 57)
#         id  regionname                                        countryname  \
# 0  P162228       Other                                        World;World
# 1  P163962      Africa  Democratic Republic of the Congo;Democratic Re...
# 2  P167672  South Asia  People's Republic of Bangladesh;People's Repub...
# 3  P158768  South Asia  Islamic  Republic of Afghanistan;Islamic  Repu...
# 4  P161364      Africa  Federal Republic of Nigeria;Federal Republic o...
#
#   prodline                  lendinginstr lendinginstrtype  \
# 0       RE  Investment Project Financing               IN
# 1       PE  Investment Project Financing               IN
# 2       PE  Investment Project Financing               IN
# 3       PE  Investment Project Financing               IN
# 4       PE  Investment Project Financing               IN
#
#   envassesmentcategorycode supplementprojectflg productlinetype  \
# 0                        C                    N               L
# ...

# %%
df_projects.isnull().sum()/df_projects.shape[0]
# Out:
# id                          0.000000
# regionname                  0.000000
# countryname                 0.000000
# prodline                    0.000000
# lendinginstr                0.013481
# lendinginstrtype            0.013481
# envassesmentcategorycode    0.318446
# supplementprojectflg        0.002904
# productlinetype             0.000000
# projectstatusdisplay        0.000219
# status                      0.000219
# project_name                0.000000
# boardapprovaldate           0.082420
# board_approval_month        0.082420
# closingdate                 0.183527
# lendprojectcost             0.006850
# ibrdcommamt                 0.000000
# idacommamt                  0.000000
# totalamt                    0.000000
# grantamt                    0.000000
# borrower                    0.324364
# impagency                   0.334119
# url                         0.000000
# projectdoc                  1.000000
# majorsector_percent         1.000000
# ...

# %%
# Read in population dataset
#the dataset cannot be read by read_csv method
with open('population_data.csv') as f:
    lines = f.readlines()

i = 0

for line in lines:
    if i<5:  
        print(line)
        i+=1
    else:
        break
# Out:
# ﻿"Data Source","World Development Indicators",
#
#
#
# "Last Updated Date","2018-06-28",
#
#
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017",

# %%
#the first 4 lines of the dataset contains no data, skip these rows in read csv
population_df = pd.read_csv('population_data.csv',skiprows = 4)

# %%
print(population_df.shape)
population_df.head()
# Out:
# (264, 63)
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965     ...       \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0     ...
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0     ...
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0     ...
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0     ...
# 4    14375.0    15370.0    16412.0    17469.0    18549.0     ...
#
#          2009        2010        2011        2012        2013        2014  \
# ...

# %%
population_df.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 62       264
# 1973                4
# 1985                4
# 1984                4
# 1983                4
# 1982                4
# 1981                4
# 1980                4
# 1979                4
# 1978                4
# 1977                4
# 1976                4
# 1975                4
# 1974                4
# 1972                4
# 1988                4
# 1971                4
# 1970                4
# 1969                4
# 1968                4
# 1967                4
# 1966                4
# 1965                4
# 1964                4
# 1963                4
# 1962                4
# 1961                4
# 1960                4
# 1986                4
# 1987                4
#                  ...
# 1994                3
# 2016                2
# 2017                2
# 2012                2
# 2013                2
# 2014                2
# 2015                2
# 1997                2
# 1996                2
# 1995                2
# ...

# %% [markdown]
# 1 column is filled with N/A
